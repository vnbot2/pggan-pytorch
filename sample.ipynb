# %%
from common import *

# %%
# !ls data
# Out:
# evaluation_script.zip	      motobike		    training_dataset.zip.1
# imagenet-sample-train.tar.gz  motor_gen_128.zip
# moto_mask		      training_dataset.zip

# %%
paths = glob.glob('./data/moto_mask/*')

# %%
paths[:3]
# Out:
# ['./data/moto_mask/Motorxsjs7gxlsmallMotor.jpg.png',
#  './data/moto_mask/MotorzhbobcrmsmallMotor.jpg.png',
#  './data/moto_mask/94_c2fc20d0_7ff1_6a7f_fcd3_70b97048c0eb_2019_08_24_03_07_47_0_l_1568719569464_14053.jpg.png']

# %%
import pyson.vision as pv

# %%
img = cv2.imread(paths[5], cv2.IMREAD_UNCHANGED)

# %%
# plt.figure(dpi=200)
# plt.imshow(img[...,:3][:,:,::-1])
# plt.imshow(img[...,3], alpha=.3)
# plt.show()

# %%
mask = img[...,-1]

# %%
pv.show(mask)

# %%
mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, np.ones([10, 10]))
pv.show(mask)

# %%
cnts, hiers = pv.find_contours(mask)

# %%
# Out:
# 4
